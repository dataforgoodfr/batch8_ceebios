# %% [markdown]
# ## -  Exploration de la base de data open source
#
# ## -  Run Scispacy on some paper abstracts
#
#
# by Christian Maréchal

# %% [markdown]
# - a script has been created from this notebook, (cf ./base_open_source/data_base_exploration.py)
# it can be used as library or main script in purpoose to load downloaded gz base onto a server

# %% [raw]
# https://www.notion.so/Publications-Scientifiques-APIs-f0ee5df762f049e29584cacd4f456efb
# http://s2-public-api-prod.us-west-2.elasticbeanstalk.com/corpus/
#
# wget https://s3-us-west-2.amazonaws.com/ai2-s2-research-public/open-corpus/2020-11-06/manifest.txt
# wget -B https://s3-us-west-2.amazonaws.com/ai2-s2-research-public/open-corpus/2020-11-06/ -i manifest.txt

# %%
import glob   
import json

import gzip
import io

import ntpath
import pandas as pd
import pprint
pp = pprint.PrettyPrinter(2)

import sys
sys.path.append('../base_open_source')

from scispacy_lib import explore__text_byScispacy # this script would win to be added into an other directory
# Out:
# C:\Users\CHRISTIAN\AppData\Roaming\Python\Python36\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_core_sci_sm' (0.2.4) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# - local directory where gz files are dowbloaded

# %%
path =  "D:/ecomdataforgoodfr/Ceebios/base_open_source"

# %% [markdown]
# - some useful function, we can exctract json data directly from compressed gz files

# %%
def get_gz_tab_files(path):
    ''' create a list of compressed gz files downloades '''
    path2 = path + '/*.gz'
    path3 = path + '/**/*.gz'

    
    tab_files = glob.glob(path2)   
    tab_files3 = glob.glob(path3)   
    return tab_files + tab_files3


def load_one_gz_file(gz_file):
    ''' extract json data from compressed file '''
    tab_doc = []
    gz = gzip.open(gz_file, 'rb')
    f = io.BufferedReader(gz)
    for line in f.readlines():
         tab_doc.append(json.loads(line))         
    gz.close()
    return tab_doc

# %% [markdown]
# - let scan gz file names

# %%
tab_files = get_gz_tab_files(path)
print('Nb of commpressed gz files:', len(tab_files))

for gz_file in tab_files:
    print('file:', ntpath.basename(gz_file))
# Out:
# Nb of commpressed gz files: 87
# file: s2-corpus-000.gz
# file: s2-corpus-001.gz
# file: s2-corpus-002.gz
# file: s2-corpus-003.gz
# file: s2-corpus-004.gz
# file: s2-corpus-005.gz
# file: s2-corpus-006.gz
# file: s2-corpus-007.gz
# file: s2-corpus-008.gz
# file: s2-corpus-009.gz
# file: s2-corpus-010.gz
# file: s2-corpus-011.gz
# file: s2-corpus-012.gz
# file: s2-corpus-013.gz
# file: s2-corpus-014.gz
# file: s2-corpus-015.gz
# file: s2-corpus-016.gz
# file: s2-corpus-017.gz
# file: s2-corpus-018.gz
# file: s2-corpus-019.gz
# file: s2-corpus-020.gz
# file: s2-corpus-021.gz
# file: s2-corpus-022.gz
# file: s2-corpus-023.gz
# file: s2-corpus-024.gz
# file: s2-corpus-025.gz
# file: s2-corpus-026.gz
# file: s2-corpus-027.gz
# file: s2-corpus-028.gz
# file: s2-corpus-029.gz
# file: s2-corpus-030.gz
# file: s2-corpus-031.gz
# file: s2-corpus-032.gz
# file: s2-corpus-033.gz
# file: s2-corpus-034.gz
# file: s2-corpus-035.gz
# file: s2-corpus-036.gz
# file: s2-corpus-037.gz
# ...

# %% [markdown]
# - let's read the first one

# %%
gz_file = tab_files[0]
tab_doc = load_one_gz_file(gz_file)
print('file:', ntpath.basename(gz_file), 'length:', len(tab_doc))
print()
df = pd.DataFrame(tab_doc)
print('dataframe shape', df.shape)
print('columns')
print(list(df.columns))
display(df.head(1))
# Out:
# file: s2-corpus-000.gz length: 32140
#
# dataframe shape (32140, 21)
# columns
# ['id', 'title', 'paperAbstract', 'authors', 'inCitations', 'outCitations', 'year', 's2Url', 'sources', 'pdfUrls', 'venue', 'journalName', 'journalVolume', 'journalPages', 'doi', 'doiUrl', 'pmid', 'fieldsOfStudy', 'magId', 's2PdfUrl', 'entities']
#                                          id  \
# 0  33b237709dbd53953a750355115b57ccb6690da1
#
#                                                title paperAbstract  \
# 0  USING PHOTO IMAGES TO DETERMINE THE GEOMETRIC ...
#
#                                              authors inCitations outCitations  \
# 0  [{'name': 'E  Popov', 'ids': ['144112922']}, {...          []           []
#
#      year                                              s2Url sources pdfUrls  \
# 0  2019.0  https://semanticscholar.org/paper/33b237709dbd...      []      []
#
#    ... journalName journalVolume journalPages                   doi  \
# ...

# %%
df.drop(['id'], axis=1, inplace=True)
display(df.head())
# Out:
#                                                title  \
# 0  USING PHOTO IMAGES TO DETERMINE THE GEOMETRIC ...
# 1  Clinical or Industrial Pharmacy? Case Studies ...
# 2  Noncoronary and coronary atherothrombotic plaq...
# 3                                      국어 명사구 접속의 연구
# 4               Who'll Take My Place : When I'm Gone
#
#                                        paperAbstract  \
# 0
# 1  Automated medication dispensing systems for ho...
# 2  In the future, the use of imaging methods to q...
# 3
# 4
#
#                                              authors  \
# 0  [{'name': 'E  Popov', 'ids': ['144112922']}, {...
# 1        [{'name': 'J  Novek', 'ids': ['47586327']}]
# 2     [{'name': 'Zahi A Fayad', 'ids': ['1886137']}]
# 3            [{'name': '최재희', 'ids': ['115087709']}]
# 4  [{'name': 'Billy  Fazioli', 'ids': ['146257415...
#
#                                          inCitations  \
# 0                                                 []
# ...

# %%
display(df['paperAbstract'].loc[1])
# Out:
# "Automated medication dispensing systems for hospital pharmacies, heralded as an important means of reducing drug errors and improving labor productivity, have also been seen as a means of furthering the transformation of the pharmacy profession from its role in dispensing prescriptions to a clinical profession concerned with treatments and patient outcomes. Automation aids this transformation by transferring the responsibility for routine dispensing to technicians performing rationalized and computer-mediated tasks. Not all pharmacists agree with these trends. Some fear a loss of professional status and employment as their knowledge is expropriated and incorporated into machinery operated by those with lesser qualifications. They fear an industrial rather than a clinical future. Their concerns are compounded by health care cutbacks. These issues were studied at two hospitals in Canada and one in France, all mid-sized public hospitals with automated unit dose drug delivery systems in
# ...

# %% [markdown]
# ### -  Run Scispacy lib  on some paper abstracts
# - the loaded Scispacy model loaded is: en_core_sci_sm

# %%
dfa = df[df['paperAbstract']!='']
dfa.reset_index(drop=True, inplace=True)
for i in range(0, 10):
    x = dfa['paperAbstract'].loc[i]
    explore__text_byScispacy(x)
# Out:
# Input text:
# ('Automated medication dispensing systems for hospital pharmacies, heralded as '
#  'an important means of reducing drug errors and improving labor productivity, '
#  'have also been seen as a means of furthering the transformation of the '
#  'pharmacy profession from its role in dispensing prescriptions to a clinical '
#  'profession concerned with treatments and patient outcomes. Automation aids '
#  'this transformation by transferring the responsibility for routine '
#  'dispensing to technicians performing rationalized and computer-mediated '
#  'tasks. Not all pharmacists agree with these trends. Some fear a loss of '
#  'professional status and employment as their knowledge is expropriated and '
#  'incorporated into machinery operated by those with lesser qualifications. '
#  'They fear an industrial rather than a clinical future. Their concerns are '
#  'compounded by health care cutbacks. These issues were studied at two '
# ...

# %%
- discussion: les abreviations trouvées ont l'air performantes
