# %% [markdown]
# ## Get all archives using http://s2-public-api-prod.us-west-2.elasticbeanstalk.com/corpus/download/
#
# Need to find a way to filter all these articles and keep only those which can be of interest to us i.e. those talking about species.
#
# Idealy we need to tag each article of interest with:
# - tag of the specie it talks about
# - tag of the genus
# - tag of the family
#
# We can base our work on:
# - paper title
# - paper abstract
#
# Our assumption is that is the author used a particular species for his article, he will mention it either in the title or the abstract (strong assumption).
#
# First I will study papers' abstract.

# %% [markdown]
# In a given gz file, we will need to drop all rows with no abstract.

# %% [markdown]
# #### Imports

# %%
import glob
import json
import pandas as pd
import gzip
import os
import io
from langdetect import detect
import scispacy                                                        
import spacy                                                        
import en_core_sci_lg
from spacy import displacy

# %%
from typing import List, Dict, Union

# %% [markdown]
# ### Get data

# %%
data_dir = "/Users/chloesekkat/Documents/batch8_ceebios/data_open_source"

# %%
def get_gz_files(data_dir: str) -> List[Dict]:
    """
    Get list of json files from gz files.
    """
    for file in os.listdir(data_dir):
        json_list = []
        if file.endswith('.gz'):
            gz = gzip.open(os.path.join(data_dir, file), 'rb')
            f = io.BufferedReader(gz)
            for line in f.readlines():
                json_list.append(json.loads(line))
            gz.close()
        return json_list

# %%
json_list = get_gz_files(data_dir)

# %%
data = pd.DataFrame(json_list)

# %%
data.shape
# Out:
# (32229, 21)

# %%
def missing_data(data: pd.DataFrame) -> pd.DataFrame:
    total = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    tt = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return(tt)

# %%
missing_data(data)
# Out:
#                Total  Percent
# id                 0  0.00000
# title              0  0.00000
# paperAbstract      0  0.00000
# authors            0  0.00000
# inCitations        0  0.00000
# outCitations       0  0.00000
# year             254  0.78811
# s2Url              0  0.00000
# sources            0  0.00000
# pdfUrls            0  0.00000
# venue              0  0.00000
# journalName        0  0.00000
# journalVolume      0  0.00000
# journalPages       0  0.00000
# doi                0  0.00000
# doiUrl             0  0.00000
# pmid               0  0.00000
# fieldsOfStudy      0  0.00000
# magId              0  0.00000
# s2PdfUrl           0  0.00000
# entities           0  0.00000

# %%
data.head()
# Out:
#                                          id  \
# 0  5cf3fcad3ee67c45f1c3d98c2b4bc22f683bfca7
# 1  9758f471a6789d32e9d684856c1b257b1fbb5546
# 2  73236ad2ede98f3f3f6acbf83a463b4afe2dd1fb
# 3  3d9a672fef4b9fe99cd948787e340d68fbf1513b
# 4  251045388ce98e901ccc7d22ae754a224c72dc28
#
#                                                title  \
# 0  Quantum phase diagrams and time-of-flight pict...
# 1  IPCC (Intergovernmental Panel on Climate Chang...
# 2  Increasing CRISPR Efficiency and Measuring Its...
# 3  Don’t You Be Telling Me How Tah Talk: Educatio...
# 4  Therapeutic effect of taurine against aluminum...
#
#                                        paperAbstract  \
# 0  By treating the hopping parameter as a perturb...
# 1  The European Science Foundation (ESF) and the ...
# 2  Genome editing of human cluster of differentia...
# 3
# 4  The aim of the study was to demonstrate the th...
#
#                                              authors  \
# 0  [{'name': 'Jun  Zhang', 'ids': ['49050562']}, ...
# 1  [{'name': 'Richard C. J. Somerville', 'ids': [...
# 2  [{'name': 'Jenny  Shapiro', 'ids': ['36049549'...
# 3  [{'name': 'LaQuita N Gresham', 'ids': ['811828...
# 4  [{'name': 'Springer-Verlag  Italia', 'ids': ['...
#
#                                          inCitations  \
# 0         [7dfd349892b456de2b60a9e9a4dedfbaeedf767f]
# 1  [eca662dc341726551b1e74e9bc86d6f9aa37b15e, efd...
# 2                                                 []
# 3                                                 []
# 4         [077ca4833b07ff8fb39501d915f43d48976c7eab]
#
#                                         outCitations    year  \
# 0  [b029856e343340fc7c034f514dc15a2ad49f6c1a, 7c8...  2016.0
# 1                                                 []  2008.0
# 2  [d83ebd27f91b75b472da63636596668da6c72059, 56c...  2020.0
# 3  [3285d0b0374acfeaeca887ba5e884d62393d5e40, 136...  2014.0
# 4  [fb93f765e84bfcbdc722c07762e247a544bae269, 21b...  2014.0
#
#                                                s2Url    sources pdfUrls  ...  \
# 0  https://semanticscholar.org/paper/5cf3fcad3ee6...         []      []  ...
# 1  https://semanticscholar.org/paper/9758f471a678...         []      []  ...
# 2  https://semanticscholar.org/paper/73236ad2ede9...  [Medline]      []  ...
# 3  https://semanticscholar.org/paper/3d9a672fef4b...         []      []  ...
# 4  https://semanticscholar.org/paper/251045388ce9...         []      []  ...
#
#                                          journalName journalVolume  \
# 0                                      Laser Physics            26
# 1
# 2  Molecular Therapy. Methods & Clinical Development            17
# 3
# 4
#
#   journalPages                            doi  \
# 0       095501  10.1088/1054-660X/26/9/095501
# 1
# 2  1097 - 1107     10.1016/j.omtm.2020.04.027
# 3
# 4
#
#                                               doiUrl      pmid  \
# 0  https://doi.org/10.1088/1054-660X%2F26%2F9%2F0...
# 1
# 2         https://doi.org/10.1016/j.omtm.2020.04.027  32478125
# 3
# 4
#
#          fieldsOfStudy       magId s2PdfUrl entities
# 0            [Physics]  2461559103                []
# 1                   []  2902693084                []
# 2  [Biology, Medicine]  3022279551                []
# 3           [Medicine]    49447698                []
# 4           [Medicine]  2327692075                []
#
# [5 rows x 21 columns]

# %%
type(data.iloc[3]["paperAbstract"])
# Out:
# str

# %% [markdown]
# We need to remove the rows with empty string.

# %%
def remove_empty_abstract(df: pd.DataFrame) -> pd.DataFrame:
    """
    Remove rows where paper abstract is an empty string.
    """
    where = df["paperAbstract"].values != ""
    return df[where]

# %%
data = remove_empty_abstract(data)

# %%
to_keep = [
    "title",
    "paperAbstract",
    "fieldsOfStudy"
]

def keep_columns(df: pd.DataFrame, cols_to_keep: List[str]) -> pd.DataFrame:
    """
    Return dataframe with wanted columns.
    """
    return df[cols_to_keep]

# %%
data = keep_columns(data, to_keep)

# %%
data.head()
# Out:
#                                                title  \
# 0  Quantum phase diagrams and time-of-flight pict...
# 1  IPCC (Intergovernmental Panel on Climate Chang...
# 2  Increasing CRISPR Efficiency and Measuring Its...
# 4  Therapeutic effect of taurine against aluminum...
# 6  Mechanism of 'crowd' in evolutionary MAS for m...
#
#                                        paperAbstract        fieldsOfStudy
# 0  By treating the hopping parameter as a perturb...            [Physics]
# 1  The European Science Foundation (ESF) and the ...                   []
# 2  Genome editing of human cluster of differentia...  [Biology, Medicine]
# 4  The aim of the study was to demonstrate the th...           [Medicine]
# 6  This work introduces a new evolutionary approa...   [Computer Science]

# %%
def keep_english_abstracts(df: pd.DataFrame) -> pd.DataFrame:
    """
    Keep only papers with abstract in english.
    """
    keep_indexes = [] # get lits of indexes that we will keep
    df = df.reset_index(drop=True)
    for i, element in enumerate(df["paperAbstract"]):
        try:
            res = detect(element)
            if res == 'en':
                keep_indexes.append(i)
        except:
            print('Error with: ', element)
            print(type(element))
    return df[df.index.isin(keep_indexes)]

# %%
data = keep_english_abstracts(data)
# Out:
# Error with:  2
# <class 'str'>
# Error with:  ............................................................................................................................................... 3
# <class 'str'>
# Error with:  3.
# <class 'str'>
# Error with:  3
# <class 'str'>
# Error with:  473
# <class 'str'>
# Error with:  5.
# <class 'str'>

# %%
data.shape
# Out:
# (15330, 3)

# %%
data.head()
# Out:
#                                                title  \
# 0  Quantum phase diagrams and time-of-flight pict...
# 1  IPCC (Intergovernmental Panel on Climate Chang...
# 2  Increasing CRISPR Efficiency and Measuring Its...
# 3  Therapeutic effect of taurine against aluminum...
# 4  Mechanism of 'crowd' in evolutionary MAS for m...
#
#                                        paperAbstract        fieldsOfStudy
# 0  By treating the hopping parameter as a perturb...            [Physics]
# 1  The European Science Foundation (ESF) and the ...                   []
# 2  Genome editing of human cluster of differentia...  [Biology, Medicine]
# 3  The aim of the study was to demonstrate the th...           [Medicine]
# 4  This work introduces a new evolutionary approa...   [Computer Science]

# %% [markdown]
# ### Exploration using SciSpacy

# %%
test = data.iloc[1]["paperAbstract"]

# %%
nlp = en_core_sci_lg.load()
doc = nlp(test)

# %%
doc.ents
# Out:
# (European Science Foundation,
#  ESF,
#  French Foundation of the Maison des Sciences de l’Homme,
#  FMSH,
#  Entre-Sciences programme,
#  conference series,
#  environmental sciences,
#  scientists,
#  humanities,
#  social sciences,
#  colleagues,
#  life,
#  natural sciences,
#  interdisciplinary conference,
#  modelling,
#  Global Change,
#  Geosciences,
#  Economics,
#  history,
#  novelty,
#  interrelations,
#  political science,
#  impact,
#  model,
#  public sphere,
#  speakers,
#  attendees,
#  Europe,
#  United States,
#  Asia,
#  construction,
#  models,
#  global change,
#  Earth sciences,
#  Economics,
#  issues,
#  Global Warning,
#  impacts,
#  risks,
#  multidisciplinary approaches,
#  public policy perspective,
#  history of,
#  science,
#  Chaired,
#  Joel Guiot,
#  climatologist,
#  European Centre,
#  Research,
#  Teaching,
#  Geosciences,
#  Environment,
#  CEREGE,
#  Aix-en-Provence,
#  Sylvie Thoron,
#  economist,
#  Aix-Marseille Research Group,
#  Quantitative Economy,
#  GREQAM,
#  Marseille,
#  conference,
#  intense,
#  discussions,
#  scientists,
#  disciplinary horizons,
#  integrative approaches,
#  sustainable,
#  development)

# %%
displacy.render(next(doc.sents), style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2abd79a396174d879341f4068ddfa6b3-0" class="displacy" width="10200" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Foundation (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">ESF)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">French</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Foundation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Maison</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Sciences</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">l’Homme (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">FMSH) (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Entre-Sciences</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">programme)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">agreed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">jointly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">develop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">conference</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">series</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">in</tspan>
#     <tspan class="displacy-ta

# %% [markdown]
# ### Load GBIF data

# %%
gbif = pd.read_csv("/Users/chloesekkat/Documents/batch8_ceebios/data/gbif_extract.csv")
gbif.head()
# Out:
#    Unnamed: 0   key  nubKey  nameKey    taxonID  sourceTaxonKey   kingdom  \
# 0           0  8003    8003  6849425  gbif:8003     156957565.0  Animalia
# 1           1  8004    8004  7068178  gbif:8004     156957851.0  Animalia
# 2           2  8005    8005  7669892  gbif:8005     156957506.0  Animalia
# 3           3  8006    8006  7718541  gbif:8006     156957210.0  Animalia
# 4           4  8007    8007  7848133  gbif:8007     156085450.0  Animalia
#
#        phylum      order         family  ...  \
# 0  Arthropoda  Amphipoda      Melitidae  ...
# 1  Arthropoda  Amphipoda   Mimonectidae  ...
# 2  Arthropoda  Amphipoda     Ochlesidae  ...
# 3  Arthropoda  Amphipoda  Oedicerotidae  ...
# 4  Arthropoda  Amphipoda       Opisidae  ...
#
#                                          publishedIn  acceptedKey  accepted  \
# 0                                                NaN          NaN       NaN
# 1                                                NaN          NaN       NaN
# 2                                                NaN          NaN       NaN
# 3  LILLJEBORG, W. (1865). On the Lysianassa magel...          NaN       NaN
# 4  Lowry, J. K.; Stoddart, H. E. (1995). The Amph...          NaN       NaN
#
#    proParteKey  genus genusKey species  speciesKey basionymKey basionym
# 0          NaN    NaN      NaN     NaN         NaN         NaN      NaN
# 1          NaN    NaN      NaN     NaN         NaN         NaN      NaN
# 2          NaN    NaN      NaN     NaN         NaN         NaN      NaN
# 3          NaN    NaN      NaN     NaN         NaN         NaN      NaN
# 4          NaN    NaN      NaN     NaN         NaN         NaN      NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# Idealy we need to tag each article of interest with:
#
# - tag of the specie it talks about
# - tag of the genus
# - tag of the family

# %%
to_keep = [
    "key",
    "canonicalName",
    "family",
    "familyKey",
    "genus",
    "genusKey"
]
gbif = gbif[to_keep]

# %%
missing_data(gbif)
# Out:
#                Total   Percent
# key                0  0.000000
# canonicalName      0  0.000000
# family          1349  1.335644
# familyKey       1349  1.335644
# genus           8657  8.571287
# genusKey        8657  8.571287

# %% [markdown]
# #### What should we do about the missing values ?

# %%
gbif.shape
# Out:
# (101000, 6)

# %%
gbif = gbif.drop_duplicates()
gbif.shape
# Out:
# (101000, 6)

# %% [markdown]
# ### Load Keyword processor

# %%
from flashtext import KeywordProcessor

keyword_processor = KeywordProcessor()

for name in gbif["canonicalName"]:
    keyword_processor.add_keyword(name)

# %%
text = "Distribution and movement patterns of Antarctic blue whales Balaenoptera musculus intermedia at large temporal and spatial scales are still poorly understood. The objective of this study was to explore spatio-temporal distribution patterns of Antarctic blue whales in the Atlantic sector of the Southern Ocean,using passive acoustic monitoring data. Multi-year data were collected between 2008 and 2013 by 11 recorders deployed in the Weddell Sea and along the Greenwich meridian. Antarctic blue whale Z-calls were detected via spectrogram cross-correlation. A Blue Whale Index was developed to quantify the proportion of time during which acoustic energy from Antarctic blue whales dominatedover background noise. Our results show that Antarctic blue whales were acoustically present year-round, with most call detections between January and April.During austral summer, the number of detected calls peaked synchronously throughout the study area in mostyears, and hence, no directed meridional movement pattern was detectable. During austral winter,vocalizations were recorded at latitudes as high as 69°S, with sea ice cover exceeding 90%,suggesting that some Antarctic blue whales overwinterin Antarctic waters. Polynyas likely serve as an important habitat for baleen whales duringaustral winter, providing food and reliable access to open water for breathing. Overall, our results support increasing evidence of a complex and non-obligatory migratory behavior of Antarctic blue whales,potentially involving temporally and spatially dynamic migration routes and destinations, as well as variable timing of migration to and from the feeding grounds."

# %%
keyword_processor.extract_keywords(text)
# Out:
# []

# %% [markdown]
# Does not find "Balaenoptera musculus", we need to split all canonical names ?

# %%
where = gbif["canonicalName"].str.contains('musculus') 
gbif[where]
# Out:
#            key           canonicalName          family  familyKey  \
# 10270  1002097    Trichocerca musculus  Trichocercidae     8115.0
# 42790  1048436      Meibomeus musculus   Chrysomelidae     7780.0
# 47513  1046890       Anthicus musculus      Anthicidae     7771.0
# 47806  1047185        Vanonus musculus        Aderidae  1047172.0
# 56552  1066979   Pharaphodius musculus      Aphodiidae     2933.0
# 62966  1073160   Xenochodaeus musculus     Ochodaeidae     9523.0
# 72662  1085757  Neoathyreus ramusculus  Bolboceratidae     7720.0
# 77248  1091082    Onthophagus musculus    Scarabaeidae     5840.0
# 80296  1108020      Lepturges musculus    Cerambycidae     5602.0
# 80298  1108023      Lepturgus musculus    Cerambycidae     5602.0
#
#               genus   genusKey
# 10270   Trichocerca  1001946.0
# 42790     Meibomeus  1048435.0
# 47513      Anthicus  1046876.0
# 47806       Vanonus  1047173.0
# 56552  Pharaphodius  1066872.0
# 62966  Xenochodaeus  1073158.0
# 72662   Neoathyreus  1085749.0
# 77248   Onthophagus  1089294.0
# 80296     Urgleptes  1107917.0
# 80298     Urgleptes  1107917.0

# %% [markdown]
# ### Find keywords on all dataframe

# %%
def keep_articles_species(data: pd.DataFrame, keyword_processor: KeywordProcessor) -> pd.DataFrame:
    """
    Keep only articles for which we find a match and add a keyword column.
    The matched keywords need to be previously set in `keyword_processor`.
    """
    data = data.reset_index(drop=True)
    keep_indexes = []
    keywords = []
    for i, element in enumerate(data["paperAbstract"]):
        res = keyword_processor.extract_keywords(element)
        if len(res) > 0:
            keep_indexes.append(i)
            keywords.append(list(set(res)))
    data = data[data.index.isin(keep_indexes)]
    data["keyword"] = keywords
    return data

# %%
data = keep_articles_species(data, keyword_processor)

# %%
data.shape
# Out:
# (556, 4)

# %%
data.head()
# Out:
#                                                  title  \
# 73   Acid Content of Scent Fluid from Acanthocephal...
# 102                            A taxonomy of datatypes
# 108  Quantitative response to photoperiod and weak ...
# 121  Ability of a wash regimen to remove biofilm fr...
# 150  Synthesis and biological activities of (Z) and...
#
#                                          paperAbstract       fieldsOfStudy  \
# 73   The major component of the defensive scent flu...           [Biology]
# 102  This is the second article based on language-i...  [Computer Science]
# 108  Reproduction and wing patterns (shape and colo...                  []
# 121  The skin/implant interface of osseointegrated ...          [Medicine]
# 150  Synthesis of Z and E ethenyl acyclonucleosides...          [Medicine]
#
#                                                keyword
# 73                                    [Acanthocephala]
# 102                                             [Goes]
# 108  [Allomyrina, Nymphalidae, Lepidoptera, Gymnopl...
# 121                                         [Bacteria]
# 150                                          [Viruses]

# %% [markdown]
# ### Add keys to dataframe

# %%
def get_dict_name_keys(df: pd.DataFrame) -> Dict[str, Union[int, List[float]]]:
    """
    Construct a dictionnary mapping each canonical name
    to its corresponding key, familyKey and genusKey when available.
    """
    where = df["genusKey"].isna() & df["familyKey"].isna()
    df_tmp = df[where]
    dict_1 = df_tmp.set_index("canonicalName")["key"].to_dict()
    df = df[~where]
    
    where = df["genusKey"].isna()
    df_tmp = df[where]
    df_tmp["allKeys"] = df_tmp[["key", "familyKey"]].values.tolist()
    dict_2 = df_tmp.set_index("canonicalName")["allKeys"].to_dict()
    df = df[~where]
    
    where = df["family"].isna()
    df_tmp = df[~where]
    df_tmp["allKeys"] = df_tmp[["key", "genusKey"]].values.tolist()
    dict_3 = df_tmp.set_index("canonicalName")["allKeys"].to_dict()
    return {**dict_1, **dict_2, **dict_3}

# %%
dict_name_keys = get_dict_name_keys(gbif)
# Out:
# <ipython-input-40-d5a8aa4439d7>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["allKeys"] = df_tmp[["key", "familyKey"]].values.tolist()
# <ipython-input-40-d5a8aa4439d7>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["allKeys"] = df_tmp[["key", "genusKey"]].values.tolist()

# %%
def from_str_to_keys(liste: List[str], dict_map: Union[int, List[float]]) -> List[str]:
    """
    Convert a list of keywords into a list of corresponding keys.
    Corresponding keys are deduced from `dict_map`.
    """
    to_return = []
    if len(liste) > 1:
        for name in liste:
            key = dict_map[name.strip("''")]
            if type(key) == list:
                to_return += key
            else:
                to_return.append(key)
    else:
        key = dict_map[liste[0].strip("''")]
        if type(key) == list:
                to_return += key
        else:
                to_return.append(key)
    return to_return

# %%
data["paper_keys"] = data["keyword"].apply(lambda x: from_str_to_keys(x, dict_name_keys))

# %%
data.head()
# Out:
#                                                  title  \
# 73   Acid Content of Scent Fluid from Acanthocephal...
# 102                            A taxonomy of datatypes
# 108  Quantitative response to photoperiod and weak ...
# 121  Ability of a wash regimen to remove biofilm fr...
# 150  Synthesis and biological activities of (Z) and...
#
#                                          paperAbstract       fieldsOfStudy  \
# 73   The major component of the defensive scent flu...           [Biology]
# 102  This is the second article based on language-i...  [Computer Science]
# 108  Reproduction and wing patterns (shape and colo...                  []
# 121  The skin/implant interface of osseointegrated ...          [Medicine]
# 150  Synthesis of Z and E ethenyl acyclonucleosides...          [Medicine]
#
#                                                keyword  \
# 73                                    [Acanthocephala]
# 102                                             [Goes]
# 108  [Allomyrina, Nymphalidae, Lepidoptera, Gymnopl...
# 121                                         [Bacteria]
# 150                                          [Viruses]
#
#                                             paper_keys
# 73                                                [67]
# 102                             [1125298.0, 1125298.0]
# 108  [1075673.0, 1075673.0, 7017.0, 7017.0, 797, 10...
# 121                                                [3]
# 150                                                [8]
