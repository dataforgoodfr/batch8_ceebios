# %% [markdown]
# # Exploration of the MNHN mammals dataset

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# - https://science.mnhn.fr/all/search
# - https://www.gbif.org/dataset/3959ee49-7678-4a88-9049-5dfc55ccebf3

# %% [markdown]
# # Reading data

# %%
# !ls ../data/gbif_mammals
# Out:
# citations.txt
# dataset
# meta.xml
# metadata.xml
# multimedia.txt
# occurrence.txt
# rights.txt
# verbatim.txt

# %%
data = pd.read_csv("../data/gbif_mammals/occurrence.txt",sep = "\t")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (168,216,241,242,243,244,245,246,247,248) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#        gbifID  abstract  accessRights  accrualMethod  accrualPeriodicity  \
# 0  2863210302       NaN           NaN            NaN                 NaN
# 1  2863210301       NaN           NaN            NaN                 NaN
# 2  2863209301       NaN           NaN            NaN                 NaN
# 3  2863208301       NaN           NaN            NaN                 NaN
# 4  2823508301       NaN           NaN            NaN                 NaN
#
#    accrualPolicy  alternative  audience  available  bibliographicCitation  \
# 0            NaN          NaN       NaN        NaN                    NaN
# 1            NaN          NaN       NaN        NaN                    NaN
# 2            NaN          NaN       NaN        NaN                    NaN
# 3            NaN          NaN       NaN        NaN                    NaN
# 4            NaN          NaN       NaN        NaN                    NaN
#
#    ...  recordedByID  identifiedByID  level0Gid  level0Name  level1Gid  \
# 0  ...           NaN             NaN        NaN         NaN        NaN
# 1  ...           NaN             NaN        NaN         NaN        NaN
# 2  ...           NaN             NaN        NaN         NaN        NaN
# 3  ...           NaN             NaN        NaN         NaN        NaN
# 4  ...           NaN             NaN        NaN         NaN        NaN
#
#    level1Name  level2Gid  level2Name  level3Gid  level3Name
# 0         NaN        NaN         NaN        NaN         NaN
# 1         NaN        NaN         NaN        NaN         NaN
# 2         NaN        NaN         NaN        NaN         NaN
# 3         NaN        NaN         NaN        NaN         NaN
# 4         NaN        NaN         NaN        NaN         NaN
#
# [5 rows x 249 columns]

# %%
data.shape
# Out:
# (95995, 249)

# %%
data.iloc[0].dropna()
# Out:
# gbifID                                                           2863210302
# identifier                http://coldb.mnhn.fr/catalognumber/mnhn/zm/ac-...
# license                                                           CC_BY_4_0
# modified                                               2011-03-02T15:17:35Z
# institutionCode                                                        MNHN
# collectionCode                                                           ZM
# basisOfRecord                                            PRESERVED_SPECIMEN
# occurrenceID              http://coldb.mnhn.fr/catalognumber/mnhn/zm/ac-...
# catalogNumber                                                    AC-1998-14
# recordedBy                                        Couté, Alain|Couté, Alain
# occurrenceStatus                                                    PRESENT
# eventDate                                               1997-10-01T00:00:00
# year                                                                   1997
# month                                                                    10
# continent                                                            AFRICA
# countryCode                                                              MG
# locality                                          Ile Glorieuse, île du Lys
# scientificName                           Tursiops aduncus (Ehrenberg, 1833)
# kingdom                                                            Animalia
# phylum                                                             Chordata
# class                                                              Mammalia
# order                                                               Cetacea
# family                                                          Delphinidae
# genus                                                              Tursiops
# specificEpithet                                                     aduncus
# taxonRank                                                           SPECIES
# taxonomicStatus                                                    ACCEPTED
# datasetKey                             3959ee49-7678-4a88-9049-5dfc55ccebf3
# publishingCountry                                                        FR
# lastInterpreted                                    2020-09-22T15:55:13.040Z
# hasCoordinate                                                         False
# hasGeospatialIssues                                                   False
# taxonKey                                                            2440455
# acceptedTaxonKey                                                2.44046e+06
# kingdomKey                                                                1
# phylumKey                                                                44
# classKey                                                                359
# orderKey                                                                733
# familyKey                                                              5314
# genusKey                                                        2.44045e+06
# speciesKey                                                      2.44046e+06
# species                                                    Tursiops aduncus
# genericName                                                        Tursiops
# acceptedScientificName                   Tursiops aduncus (Ehrenberg, 1833)
# verbatimScientificName                     Tursiops aduncus Ehrenberg, 1833
# protocol                                                        DWC_ARCHIVE
# lastParsed                                         2020-09-22T15:55:13.040Z
# lastCrawled                                        2020-09-22T15:53:14.340Z
# repatriated                                                            True
# Name: 0, dtype: object

# %% [markdown]
# # Data exploration

# %%
important_columns = [
    "countryCode",
    "locality",
    'kingdom',
    'phylum', 'class', 'order', 'family', 'genus',
    "specificEpithet",
    "species",
    "genericName",
    "acceptedScientificName",
]

# %%
for col in important_columns:
    data[col].value_counts().head(10).sort_values().plot(kind = "barh",figsize = (5,4),title = col)
    plt.show()

# %% [markdown]
# # Link with wikipedia

# %%
import wikipedia

# %%
wikipedia.search("serpent")
# Out:
# ['Serpent',
#  'Serpents in the Bible',
#  'Serpent Mound',
#  'Jörmungandr',
#  'Serpent (symbolism)',
#  'Rainbow Serpent',
#  'Serpentor',
#  'Sea serpent',
#  'Winged serpent',
#  'Nehushtan']

# %%
snake = wikipedia.page("Snake")

# %%
snake.
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/8/89/Brazilian_Expeditionary_Forces_insignia_%28smoking_snake%29.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/6/60/Carpet_snake.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/26/Eierschlange_frisst_Zwergwachtelei.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/2/2b/Eupodophis_descouensi_Holotype.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/1/11/Eupodophis_descouensi_Holotype_hind_leg.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/b/b8/Foot_prints_of_Snake.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/86/Golden_Uraes_Cobra_Tutankhamun%27s_Throne.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/79/Golden_tree_snake.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/3/35/Guangzhou-snakes-at-restaurant-0457.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/ed/Lizardicon.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/8a/Longane%2C_Sicily.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d3/Medusa_by_Carvaggio.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/99/Neonate_sidewinder_sidewinding_with_tracks_unlabeled.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/5/5b/Nerodia_sipedon_shedding.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/6/6a/Pachyrhachis_problematicus_45.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/3/37/PikiWiki_Israel_37648_Nature_and_Colors.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/46/Ptyas_gab_fbi.png',
#  'https://upload.wikimedia.org/wikipedia/commons/7/74/Red_Pencil_Icon.png',
#  'https://upload.wikimedia.org/wikipedia/commons/a/aa/Red_milk_snake.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/8/84/Rod_of_asclepius.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4d/Snake-anatomy.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/97/Snake_Skeletons.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a8/Snake_bite_symptoms.png',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d5/Snake_icon.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/ae/Snake_in_basket.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4b/Snake_meat.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f5/Snakes_Diversity.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/8/8b/Tetrapodophis_amplectus_3483.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/ae/ViperaBerusFang.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/1/1b/Wiki_snake_eats_mouse.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/fa/Wikiquote-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/99/Wiktionary-logo-en-v2.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/d/d4/World_distribution_of_snakes.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/7/76/Coast_Garter_Snake.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/4/4a/Commons-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/e/e7/Leptotyphlops_carlae.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/c/c8/Mixco_Viejo_ballcourt_marker.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg',
#  'https://upload.wikimedia.org/wikipedia/en/9/99/Question_book-new.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/3/3d/Salvage_Scrap_propaganda_poster_crop2.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/1/1b/Semi-protection-shackle.svg']
